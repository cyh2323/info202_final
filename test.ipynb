# %%
import streamlit as st
import pandas as pd

# 데이터 불러오기
df = pd.read_csv("bank_products.csv")

st.title("Bank Product Recommender 💳")

# 사용자 입력
purpose = st.selectbox("What is your goal?", ["Travel", "Cashback", "Savings"])
annual_fee = st.checkbox("No annual fee only")

# 필터링 로직
filtered = df[df["product_type"] == "credit_card"]

if purpose == "Travel":
    filtered = filtered[filtered["reward_type"].str.contains("travel", case=False, na=False)]
elif purpose == "Cashback":
    filtered = filtered[filtered["reward_type"].str.contains("cashback", case=False, na=False)]

if annual_fee:
    filtered = filtered[filtered["annual_fee"] == 0]

st.write("### Recommended Products")
st.dataframe(filtered[["product_name", "bank", "reward_rate", "annual_fee"]])
# Out:
# 2025-11-12 15:59:07.704 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.586
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\cyh23\anaconda3\envs\info206a\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-12 15:59:08.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.594 Session state does not function when running a script without `streamlit run`
# 2025-11-12 15:59:08.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 15:59:08.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
